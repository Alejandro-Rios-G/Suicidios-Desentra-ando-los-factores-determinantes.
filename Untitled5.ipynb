# %% [markdown]
# <a href="https://colab.research.google.com/github/Alejandro-Rios-G/Suicidios-Desentra-ando-los-factores-determinantes./blob/main/Untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

# %%
import pandas as pd
archivo_excel = "/content/2) Suicidios Tableros Año 2015.xlsx"
datos = pd.read_excel(archivo_excel)
print(datos.head())
# Out:
#    Unnamed: 0 Unnamed: 1                      Unnamed: 2
# 0         NaN        NaN  SUICIDIOS EN COLOMBIA AÑO 2015
# 1         NaN        NaN                             NaN
# 2         NaN        NaN                             NaN
# 3         NaN     NÚMERO                   MENÚ TABLEROS
# 4         NaN          1                             NaN
# /usr/local/lib/python3.10/dist-packages/openpyxl/worksheet/_reader.py:329: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)

# %%
datos.head()
# Out:
#    Unnamed: 0 Unnamed: 1                      Unnamed: 2
# 0         NaN        NaN  SUICIDIOS EN COLOMBIA AÑO 2015
# 1         NaN        NaN                             NaN
# 2         NaN        NaN                             NaN
# 3         NaN     NÚMERO                   MENÚ TABLEROS
# 4         NaN          1                             NaN

# %%
import pandas as pd


archivos_excel = [
    "/content/2) Suicidios Tableros Año 2015.xlsx",
    "/content/2-Suicidios Tableros Año 2016.xlsx",
    "/content/2-Suicidios. Colombia, 2017.xlsx",
    "/content/2-Suicidios. Colombia, 2018.xlsx",
    "/content/2-Suicidios. Colombia, 2019.xlsx",
    "/content/2-Suicidios. Colombia, 2020.xlsx",
    "/content/2-Suicidios. Colombia, 2021.xlsx",
    "/content/2_Suicidios_Colombia_2022.xlsx"
]


dataframes = []

for archivo in archivos_excel:
    df = pd.read_excel(archivo)
    dataframes.append(df)

datos_completos = pd.concat(dataframes, ignore_index=True)

print(datos_completos.head())
# Out:
# /usr/local/lib/python3.10/dist-packages/openpyxl/worksheet/_reader.py:329: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)
#    Unnamed: 0 Unnamed: 1                      Unnamed: 2
# 0         NaN        NaN  SUICIDIOS EN COLOMBIA AÑO 2015
# 1         NaN        NaN                             NaN
# 2         NaN        NaN                             NaN
# 3         NaN     NÚMERO                   MENÚ TABLEROS
# 4         NaN          1                             NaN

# %%
datos_completos.tail()
# Out:
#     Unnamed: 0                                         Unnamed: 1 Unnamed: 2
# 87         NaN                                                NaN        NaN
# 88         NaN                                            FUENTE:        NaN
# 89         NaN  FUENTE: Instituto Nacional de Medicina Legal y...        NaN
# 90         NaN  Grupo: Centro de Referencia Nacional Sobre la ...        NaN
# 91         NaN  Base: Sistema de Información Red de Desapareci...        NaN

# %%
import pandas as pd

archivos_excel = "/content/2) Suicidios Tableros Año 2022.xlsx"


df = pd.read_excel(archivo_excel, sheet_name="GENERAL COLOMBIA")

print(df.columns)
# Out:
# Index(['Tabla. Suicidios; número de casos según variable del hecho, categoría de edad y sexo de la víctima; Colombia. Año 2015',
#        'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5',
#        'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9'],
#       dtype='object')
# /usr/local/lib/python3.10/dist-packages/openpyxl/worksheet/_reader.py:329: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)

# %%
# !pip install unidecode
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 235.5/235.5 kB 4.6 MB/s eta 0:00:00
# ...

# %%
# !pip install unidecode

import os
import pandas as pd
import numpy as np
from unidecode import unidecode

archivos = [
    "/content/2) Suicidios Tableros Año 2015.xlsx",
    "/content/2-Suicidios Tableros Año 2016.xlsx",
    "/content/2-Suicidios. Colombia, 2017.xlsx",
    "/content/2-Suicidios. Colombia, 2018.xlsx",
    "/content/2-Suicidios. Colombia, 2019.xlsx",
    "/content/2-Suicidios. Colombia, 2020.xlsx",
    "/content/2-Suicidios. Colombia, 2021.xlsx",
    "/content/2_Suicidios_Colombia_2022.xlsx"
]

all_dfs = []

for archivo in archivos:
    if os.path.isfile(archivo):
        try:
            temp = pd.read_excel(archivo)

            temp.columns = [unidecode(str(col)) for col in temp.columns]

            temp.columns = temp.columns.str.replace(' ', '_')

            temp.columns = temp.columns.str.strip()

            temp.columns = temp.columns.str.lower()

            temp.replace('-', np.nan, inplace=True)

            all_dfs.append(temp)
            print(f"Archivo leído exitosamente: {archivo}")
        except Exception as e:
            print(f"Error al leer el archivo {archivo}: {e}")
    else:
        print(f"Archivo no encontrado: {archivo}")


for i in range(len(all_dfs)):
    all_dfs[i].rename(columns=renaming, inplace=True)
df_f = pd.concat(all_dfs, axis=0)

print(df_f.head())
# Out:
# ...
# /usr/local/lib/python3.10/dist-packages/openpyxl/worksheet/_reader.py:329: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)
# Archivo leído exitosamente: /content/2) Suicidios Tableros Año 2015.xlsx
# Archivo leído exitosamente: /content/2-Suicidios Tableros Año 2016.xlsx
# Archivo leído exitosamente: /content/2-Suicidios. Colombia, 2017.xlsx
# Archivo leído exitosamente: /content/2-Suicidios. Colombia, 2018.xlsx
# Archivo leído exitosamente: /content/2-Suicidios. Colombia, 2019.xlsx
# Archivo leído exitosamente: /content/2-Suicidios. Colombia, 2020.xlsx
# Archivo leído exitosamente: /content/2-Suicidios. Colombia, 2021.xlsx
# Archivo leído exitosamente: /content/2_Suicidios_Colombia_2022.xlsx
#    unnamed:_0 unnamed:_1                      unnamed:_2
# 0         NaN        NaN  SUICIDIOS EN COLOMBIA AÑO 2015
# 1         NaN        NaN                             NaN
# 2         NaN        NaN                             NaN
# ...

# %%
import os
import pandas as pd

archivos = [
    "/content/2) Suicidios Tableros Año 2015.xlsx",
    "/content/2-Suicidios Tableros Año 2016.xlsx",
    "/content/2-Suicidios. Colombia, 2017.xlsx",
    "/content/2-Suicidios. Colombia, 2018.xlsx",
    "/content/2-Suicidios. Colombia, 2019.xlsx",
    "/content/2-Suicidios. Colombia, 2020.xlsx",
    "/content/2-Suicidios. Colombia, 2021.xlsx",
    "/content/2_Suicidios_Colombia_2022.xlsx"
]

for archivo in archivos:
    if os.path.isfile(archivo):
        try:
            xls = pd.ExcelFile(archivo)
            print(f"Las hojas en el archivo '{archivo}' son: {xls.sheet_names}")
        except Exception as e:
            print(f"Error al leer el archivo {archivo}: {e}")
    else:
        print(f"Archivo no encontrado: {archivo}")
# Out:
# Las hojas en el archivo '/content/2) Suicidios Tableros Año 2015.xlsx' son: ['MENU SUICIDIOS 2015', 'GENERAL COLOMBIA', 'DEPARTAMENTO Y MUNICIPIO', 'DEPARTAMENTO DEL HECHO', 'MUNICIPIO DEL HECHO', 'BOGOTÁ D.C']
# Las hojas en el archivo '/content/2-Suicidios Tableros Año 2016.xlsx' son: ['MENÚ SUICIDIOS 2016', 'GENERAL COLOMBIA', 'DEPARTAMENTO Y MUNICIPIO', 'DEPARTAMENTO DEL HECHO', 'MUNICIPIO DEL HECHO', 'BOGOTÁ D.C']
# Las hojas en el archivo '/content/2-Suicidios. Colombia, 2017.xlsx' son: ['MENÚ SUICIDIOS 2017', 'GENERAL COLOMBIA', 'DEPARTAMENTO Y MUNICIPIO', 'DEPARTAMENTO DEL HECHO', 'MUNICIPIO DEL HECHO', 'BOGOTÁ D.C']
# Las hojas en el archivo '/content/2-Suicidios. Colombia, 2018.xlsx' son: ['MENÚ SUICIDIOS 2018', 'GENERAL COLOMBIA', 'DEPARTAMENTO Y MUNICIPIO', 'DEPARTAMENTO DEL HECHO', 'MUNICIPIO DEL HECHO', 'BOGOTÁ D.C']
# ...

# %%
import os
import pandas as pd

archivos = [
    "/content/2) Suicidios Tableros Año 2015.xlsx",
    "/content/2-Suicidios Tableros Año 2016.xlsx",
    "/content/2-Suicidios. Colombia, 2017.xlsx",
    "/content/2-Suicidios. Colombia, 2018.xlsx",
    "/content/2-Suicidios. Colombia, 2019.xlsx",
    "/content/2-Suicidios. Colombia, 2020.xlsx",
    "/content/2-Suicidios. Colombia, 2021.xlsx",
    "/content/2_Suicidios_Colombia_2022.xlsx"
]

hoja = "GENERAL COLOMBIA"

for archivo in archivos:
    if os.path.isfile(archivo):
        try:
            temp = pd.read_excel(archivo, sheet_name=hoja)
            print(f"Contenido de la hoja '{hoja}' en el archivo '{archivo}':")
            print(temp)
        except Exception as e:
            print(f"Error al leer la hoja '{hoja}' en el archivo '{archivo}': {e}")
    else:
        print(f"Archivo no encontrado: {archivo}")
# Out:
# /usr/local/lib/python3.10/dist-packages/openpyxl/worksheet/_reader.py:329: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)
# Contenido de la hoja 'GENERAL COLOMBIA' en el archivo '/content/2) Suicidios Tableros Año 2015.xlsx':
#     Tabla. Suicidios; número de casos según variable del hecho, categoría de edad y sexo de la víctima; Colombia. Año 2015  \
# 0               SUICIDIOS AÑO 2015 / CATEGORÍA DE EDAD
# 1                                      VARIABLE / SEXO
# 2                              VARIABLE: GRUPO DE EDAD
# 3                                            (10 a 14)
# 4                                            (15 a 17)
# ..                                                 ...
# 187                                              TOTAL
# 188  Rango de edad*: No se presentaron casos en el ...
# 189  FUENTE: Instituto Nacional de Medicina Legal y...
# 190  Grupo: Centro de Referencia Nacional Sobre la ...
# ...

# %% [markdown]
# # Sección nueva
